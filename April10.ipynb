# %% [markdown]
# <a href="https://colab.research.google.com/github/Subham0075/Data_Analysis_Datasets/blob/main/April10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hell")
# Out:
# hell

# %%
import numpy as np

# %%
s = np.random.randint(1,10,(3,3))
print(s)
# Out:
# [[5 2 5]
#  [6 4 9]
#  [1 1 7]]

# %%
l1=[1,2,3,5,7,8]
l2=[6,8,5,3,7,9]
l3=[5,2,6,-8,3,-9]
l4=[6,3,87,3,84,3]
a1=np.array([l1,l2,l3,l4])
a1
# Out:
# array([[ 1,  2,  3,  5,  7,  8],
#        [ 6,  8,  5,  3,  7,  9],
#        [ 5,  2,  6, -8,  3, -9],
#        [ 6,  3, 87,  3, 84,  3]])

# %%
a1[1:3:,1::2]
# Out:
# array([[ 8,  3,  9],
#        [ 2, -8, -9]])

# %%
a1[0:4:3,2:5:]
# Out:
# array([[ 3,  5,  7],
#        [87,  3, 84]])

# %%
a1[0::,-1:-6:-2]
# Out:
# array([[ 8,  5,  2],
#        [ 9,  3,  8],
#        [-9, -8,  2],
#        [ 3,  3,  3]])

# %%
a=np.array([2,3,5,6])
b=np.array([4,5,7,8])
np.concatenate((a,b))
# Out:
# array([2, 3, 5, 6, 4, 5, 7, 8])

# %%
a1=np.random.randint(1,10,(2,2))
b1=np.random.randint(1,10,(2,2))
print(a1)
print(b1)
# Out:
# [[5 1]
#  [9 2]]
# [[4 3]
#  [9 7]]

# %%
np.concatenate((a1,b1))
# Out:
# array([[5, 1],
#        [9, 2],
#        [4, 3],
#        [9, 7]])

# %%
np.concatenate((a1,b1),axis=1)
# Out:
# array([[5, 1, 4, 3],
#        [9, 2, 9, 7]])

# %%
np.hstack((a1,b1))
# Out:
# array([[5, 1, 4, 3],
#        [9, 2, 9, 7]])

# %%
np.vstack((a1,b1))
# Out:
# array([[5, 1],
#        [9, 2],
#        [4, 3],
#        [9, 7]])

# %%
import pandas as pd

# %%
d={'roll':45,'name':'SubhamDEV','course':'AIML'}
d1=pd.Series(d)
d1
# Out:
# roll             45
# name      SubhamDEV
# course         AIML
# dtype: object

# %%
d2 = pd.DataFrame({'roll':[45],'name':['SubhamDEV'],'course':['AIML']})
d2
# Out:
#    roll       name course
# 0    45  SubhamDEV   AIML

# %%
iris = pd.read_csv("/content/Iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris[3:15:]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# ...

# %%
iris.SepalWidthCm[0:15:2]
# Out:
# 0     3.5
# 2     3.2
# 4     3.6
# 6     3.4
# 8     2.9
# 10    3.7
# 12    3.0
# 14    4.0
# Name: SepalWidthCm, dtype: float64

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris.rename(columns={'SepalLengthCm':'SLCm','SepalWidthCm':'SWCm'})
# Out:
#       Id  SLCm  SWCm  PetalLengthCm  PetalWidthCm         Species
# 0      1   5.1   3.5            1.4           0.2     Iris-setosa
# 1      2   4.9   3.0            1.4           0.2     Iris-setosa
# 2      3   4.7   3.2            1.3           0.2     Iris-setosa
# 3      4   4.6   3.1            1.5           0.2     Iris-setosa
# 4      5   5.0   3.6            1.4           0.2     Iris-setosa
# ..   ...   ...   ...            ...           ...             ...
# 145  146   6.7   3.0            5.2           2.3  Iris-virginica
# 146  147   6.3   2.5            5.0           1.9  Iris-virginica
# 147  148   6.5   3.0            5.2           2.0  Iris-virginica
# 148  149   6.2   3.4            5.4           2.3  Iris-virginica
# 149  150   5.9   3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
iris.set_index('Id',inplace=True)

# %%
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.dtypes
# Out:
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
iris.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris.describe(include='O')
# Out:
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %%
iris.SepalLengthCm.unique()
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.4, 4.8, 4.3, 5.8, 5.7, 5.2, 5.5,
#        4.5, 5.3, 7. , 6.4, 6.9, 6.5, 6.3, 6.6, 5.9, 6. , 6.1, 5.6, 6.7,
#        6.2, 6.8, 7.1, 7.6, 7.3, 7.2, 7.7, 7.4, 7.9])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
a = iris.SepalLengthCm[1:10:1]
b = iris.SepalWidthCm[1:10:1]
c = iris.PetalLengthCm
d = iris.PetalWidthCm

# %%
plt.bar(a,b,label='Blue') LLP
plt.bar(c,d,label='Orange')
plt.title('bar plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(a,b)
plt.title('line plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()
plt.show()

# %%
plt.hist(a,bins=5,histtype='bar',rwidth=0.5)
plt.show()

# %%
plt.scatter(a,b,color='red',s=100,marker='h')
plt.show()

# %%
iris.Species.describe()
# Out:
# count             150
# unique              3
# top       Iris-setosa
# freq               50
# Name: Species, dtype: object

# %%
iris.Species.value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
a1 = ['Iris-setosa','Iris-versicolor','Iris-virginica']
b1 = [50,50,50]
c1 = ['r','y','g']

# %%
plt.pie(b1,labels=a1,colors=c1,autopct='%1.1f%%',shadow=True)
plt.show()
